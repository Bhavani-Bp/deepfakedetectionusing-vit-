# %% [markdown]
# # Slice 1: Environment Setup & verification
#
# This notebook sets up the environment on Google Colab, verifies the GPU availability, and installs necessary dependencies.

# %%
# 1. Check GPU Availability
import torch
print(f"PyTorch Version: {torch.__version__}")
print(f"CUDA Available: {torch.cuda.is_available()}")

if torch.cuda.is_available():
    print(f"Device Name: {torch.cuda.get_device_name(0)}")
else:
    print("WARNING: GPU not available. Go to Runtime > Change runtime type > Select GPU.")

# %%
# 2. Mount Google Drive
from google.colab import drive
import os

# This will prompt for authorization
drive.mount('/content/drive')

# CHANGE THIS PATH to where you uploaded the 'deepfakedetection' folder
project_path = '/content/drive/My Drive/deepfakedetection'

if os.path.exists(project_path):
    os.chdir(project_path)
    print(f"Changed working directory to: {os.getcwd()}")
else:
    print(f"WARNING: Path {project_path} not found. Please verify where you uploaded the folder.")

# %%
# 3. Install Dependencies
# !pip install -r requirements.txt

# %%
# 4. Verify Critical Imports
import cv2
import facenet_pytorch
import albumentations
import numpy as np
import matplotlib.pyplot as plt

print("All critical libraries imported successfully!")
print("Ready for Slice 2.")
